# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install  citipy
# Out:
# Collecting citipy
#   Downloading citipy-0.0.6.tar.gz (675 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 675.6/675.6 kB 3.0 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting kdtree>=0.12 (from citipy)
#   Downloading kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py) ... done
#   Created wheel for citipy: filename=citipy-0.0.6-py3-none-any.whl size=675969 sha256=79bece48168927f47be475b7ab6bb97a14eadb130afcb8762768325f405d492c
#   Stored in directory: /Users/christinaashleyzermeno/Library/Caches/pip/wheels/4b/b5/88/49107ff846ec6967b34c17d369176c591fc90ed93b706755ad
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.6 kdtree-0.16

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 573

# %%
cities
# Out:
# ['port-aux-francais',
#  'puerto natales',
#  'grytviken',
#  'blackwell',
#  'ushuaia',
#  'edinburgh of the seven seas',
#  'petropavlovsk-kamchatsky',
#  'yeed',
#  'puerto san carlos',
#  'merke',
#  'yellowknife',
#  'youssoufia',
#  'hailar',
#  'bac lieu',
#  'hadibu',
#  'labrador city',
#  'ha tien',
#  'callao',
#  'liupanshui',
#  'blackmans bay',
#  'susuman',
#  'jamestown',
#  'aasiaat',
#  'qaqortoq',
#  'hawaiian paradise park',
#  'villa bruzual',
#  'barah',
#  'acarau',
#  'waitangi',
#  'touros',
#  'tranovaho',
#  'buka',
#  'margaret river',
#  'khovd',
#  'arraial do cabo',
#  'hasaki',
#  'albany',
#  'huarmey',
#  'xaloztoc',
#  'badger',
#  'ribeirao pires',
#  'hoxtolgay',
#  'akrehamn',
#  'vishnyeva',
#  'lihue',
#  'taiohae',
#  'tual',
#  'invercargill',
#  'uliastay',
#  'kapuskasing',
#  'iskateley',
#  'pasuquin',
#  'longyearbyen',
#  'belomorsk',
#  'padam',
#  'saldanha',
#  'adamstown',
#  'rio grande',
#  'kashgar',
#  'sergeyevka',
#  'haiku-pauwela',
#  'sarakhs',
#  'stanley',
#  'atafu village',
#  'ocean city',
#  'wittenburg',
#  'bethel',
#  'hakkari',
#  'ingeniero jacobacci',
#  'tsiombe',
#  'port mathurin',
#  'salekhard',
#  'isafjordur',
#  'ciudad lazaro cardenas',
#  'viligili',
#  'tondano',
#  'ilulissat',
#  'bredasdorp',
#  'bilibino',
#  "nuku'alofa",
#  'knin',
#  'luderitz',
#  'portland',
#  'hithadhoo',
#  'pisco',
#  'upata',
#  'sola',
#  'basco',
#  'tofol',
#  'selfoss',
#  'chonchi',
#  'castillos',
#  'thompson',
#  'las varas',
#  'gadzhiyevo',
#  'sonsorol village',
#  'tiksi',
#  'bayanhongor',
#  'ancud',
#  'lorengau',
#  'yuzhno-kurilsk',
#  'mount isa',
#  'utrik',
#  'vadso',
#  'chibougamau',
#  'taiynsha',
#  'tolanaro',
#  'keflavik',
#  'avarua',
#  'mar del plata',
#  'hilo',
#  'olyokminsk',
#  'iqaluit',
#  'huicungo',
#  'kodiak',
#  'sisimiut',
#  'kerikeri',
#  'tchintabaraden',
#  'taksimo',
#  'tabuk',
#  'nemuro',
#  'georgetown',
#  'oamaru',
#  'novyy rogachik',
#  'al ghayzah',
#  'puerto ayora',
#  'kavaratti',
#  'dudinka',
#  'forster',
#  'kruisfontein',
#  'saint-denis',
#  'bima',
#  'brisas de zicatela',
#  'alofi',
#  'san antonio de pale',
#  'san patricio',
#  'nakamura',
#  'mount gambier',
#  'al artawiyah',
#  'hubli',
#  'flying fish cove',
#  "nar'yan-mar",
#  'dalhart',
#  'costa calma',
#  'portrush',
#  'vilyuysk',
#  'wajir',
#  'heihe',
#  'mahibadhoo',
#  'west island',
#  'college',
#  'vorgashor',
#  'manicore',
#  'aral',
#  'bertoua',
#  'crane',
#  'papatowai',
#  'margate',
#  'la passe',
#  'udachny',
#  'tura',
#  'woolgoolga',
#  'enewetak',
#  'whitehorse',
#  'fale old settlement',
#  'daru',
#  'urangan',
#  'saipan',
#  'vredendal',
#  'alotau',
#  'zhangye',
#  'hermanus',
#  'carutapera',
#  'punta arenas',
#  'labasa',
#  'anna regina',
#  'labytnangi',
#  'saint-philippe',
#  'urengoy',
#  'nantucket',
#  'ust-nera',
#  'tshikapa',
#  'kudat',
#  'antonio enes',
#  'lebu',
#  'ribeira grande',
#  'minas novas',
#  'sorsk',
#  'ballina',
#  'guilmaro',
#  'antalaha',
#  'caluula',
#  'cargados carajos',
#  'klyuchi',
#  'qashyr',
#  'katsuura',
#  'flin flon',
#  'altai',
#  'vernon',
#  'mata-utu',
#  'phibun mangsahan',
#  'ulladulla',
#  'port lincoln',
#  'fortuna',
#  'lucas',
#  'wailua homesteads',
#  'fortaleza',
#  'thunder bay',
#  'akureyri',
#  'colonia',
#  'fort bragg',
#  'noumea',
#  'kingston',
#  'constantia',
#  'hami',
#  'codrington',
#  'morehead city',
#  'mexico',
#  'conception bay south',
#  'poso',
#  'ituiutaba',
#  'tineo',
#  'sao jose da coroa grande',
#  'karratha',
#  'campo gallo',
#  'sorong',
#  'klaksvik',
#  'adrar',
#  'santa terezinha',
#  'hirara',
#  'palia kalan',
#  'arenapolis',
#  "kapa'a",
#  'novodvinsk',
#  'vorkuta',
#  'olonkinbyen',
#  'amasra',
#  'umluj',
#  'sept-iles',
#  'thanh hoa',
#  'port alfred',
#  'angra do heroismo',
#  'dazuocun',
#  'jordanow',
#  'swakopmund',
#  'piti village',
#  'howard springs',
#  'sao felix do xingu',
#  'ola',
#  'ouellah',
#  'waukee',
#  'tyuratam',
#  'xique xique',
#  'nyurba',
#  'batticaloa',
#  'port elizabeth',
#  'shalqar',
#  'nea moudhania',
#  'tazovsky',
#  'at taj',
#  'awjilah',
#  'new norfolk',
#  'sagua la grande',
#  'alaghsas',
#  'aykhal',
#  'east london',
#  'mejit',
#  'dabat',
#  'sitka',
#  'westport',
#  'cockburn town',
#  'murzuq',
#  'sandnessjoen',
#  'zangguy',
#  'springbok',
#  'shorkot',
#  'bayindir',
#  'cornelio procopio',
#  'mirto',
#  'kwang binh',
#  'hamilton',
#  'viradouro',
#  'plouzane',
#  'dunedin',
#  'salahonda',
#  'talnakh',
#  'guerrero negro',
#  'dongcun',
#  "mil'kovo",
#  'pimentel',
#  'ribeira brava',
#  'papao',
#  'isangel',
#  'san julian',
#  'sungai raya',
#  'najran',
#  'santo antonio',
#  'puerto aysen',
#  'rawah',
#  "'ohonua",
#  'salinopolis',
#  'gambela',
#  'kailua-kona',
#  'dalandzadgad',
#  'sao joao da ponte',
#  'talara',
#  'lompoc',
#  'pahrump',
#  'bazas',
#  'yangor',
#  'boumahra ahmed',
#  'san antonio oeste',
#  'fort mcmurray',
#  'island harbour',
#  'marsa alam',
#  'kununurra',
#  'bansi',
#  "st. john's",
#  'cabo san lucas',
#  'gizo',
#  'aitape',
#  'san luis de la loma',
#  'coquimbo',
#  'yarmouth',
#  'walvis bay',
#  'masterton',
#  'veymandoo',
#  'puerto santander',
#  'harstad',
#  'paita',
#  'pemangkat',
#  'suntar',
#  'yaren',
#  'anadyr',
#  'fuvahmulah',
#  'kataragama',
#  'maysville',
#  'cabedelo',
#  'kone',
#  'smithers',
#  'san fernando de apure',
#  'alto araguaia',
#  'kuala terengganu',
#  'popondetta',
#  'tralee',
#  'tapes',
#  'srivardhan',
#  'am timan',
#  'mahdia',
#  'arris',
#  'porto velho',
#  'kayar',
#  'kiama',
#  'kapoeta',
#  'kaga bandoro',
#  'bikenibeu village',
#  'burang',
#  'novyy urengoy',
#  'montrose',
#  'coahuayana de hidalgo',
#  'abancay',
#  'tawau',
#  'ocean shores',
#  'calama',
#  'sijunjung',
#  'broome',
#  'rongelap',
#  'mozarlandia',
#  'mathba',
#  'beloyarskiy',
#  'carnarvon',
#  'kansanshi',
#  'muscatine',
#  'puerto lempira',
#  'vilaka',
#  'sullivan',
#  'ilanskiy',
#  'al kharijah',
#  'sao vicente',
#  'panaba',
#  'dashitou',
#  'zaozersk',
#  'severo-yeniseyskiy',
#  'tariba',
#  'las heras',
#  'hovd',
#  'lata',
#  'raja',
#  'poteau',
#  'presque isle',
#  'chos malal',
#  'east grand forks',
#  'agua prieta',
#  'kushtia',
#  'wladyslawowo',
#  'gamba',
#  'ponta delgada',
#  'harlingen',
#  'altpinar',
#  'masuguru',
#  'butembo',
#  'vilyuchinsk',
#  'la ronge',
#  'bahar',
#  'bandar lampung',
#  'dan khun thot',
#  'greymouth',
#  'tazacorte',
#  'arteche',
#  'kuching',
#  'deqen',
#  'dobryanka',
#  "cooper's town",
#  'qasr-e qand',
#  'tadine',
#  'timmins',
#  'brokopondo',
#  'batangafo',
#  'gokwe',
#  'prince rupert',
#  'nova sintra',
#  'jurbarkas',
#  'simpang',
#  'quellon',
#  'bandraboua',
#  "la'ie",
#  'bhimbar',
#  'wanning',
#  'torbat-e jam',
#  'shangqiu',
#  'san jose del guaviare',
#  'xining',
#  'berezivka',
#  'mukah',
#  'tarawa',
#  'uturoa',
#  'iquique',
#  'geraldton',
#  'tahe',
#  'ikere-ekiti',
#  'praia da vitoria',
#  'kushiro',
#  'carauari',
#  "port saint john's",
#  'okhotsk',
#  'devinuwara',
#  'myitkyina',
#  'broken hill',
#  'tabou',
#  'nova xavantina',
#  'neka',
#  'aioun',
#  'terrace',
#  'griffith',
#  'itoman',
#  "priob'ye",
#  'revda',
#  'bamboo flat',
#  'buala',
#  'lerwick',
#  'saynshand',
#  'mananara',
#  'yenisehir',
#  'holualoa',
#  'lindisfarne',
#  'tocopilla',
#  "ha'il",
#  'polyarnyy',
#  'toliara',
#  'bakchar',
#  'sars',
#  'vom',
#  'lembar',
#  'puttur',
#  'afaahiti',
#  'sukhobezvodnoye',
#  'butha-buthe',
#  'ankang',
#  'launceston',
#  'dashiqiao',
#  'aizkraukle',
#  'kharhial',
#  'tamandare',
#  'goalpara',
#  'port sudan',
#  'north bend',
#  'ghanzi',
#  'freetown',
#  'charkhi dadri',
#  'mogocha',
#  'karbala',
#  'hastings',
#  'nakatsugawa',
#  'namibe',
#  'terekeka',
#  'constitucion',
#  'helston',
#  'thinadhoo',
#  'belyy yar',
#  'bossangoa',
#  'fagaras',
#  'kasimov',
#  'riverton',
#  'kota bharu',
#  'sofifi',
#  'glace bay',
#  'murun-kuren',
#  'sabang',
#  'lensk',
#  'conde',
#  'novyy urgal',
#  'nadi',
#  'aplahoue',
#  'grahamstown',
#  'box elder',
#  'caleta de carquin',
#  'bridgetown',
#  'ta`u',
#  'el triunfo',
#  'arvayheer',
#  'mili',
#  'wagar',
#  'altamira',
#  'yantzaza',
#  'manado',
#  'lazaro cardenas',
#  'almus',
#  'yarovoye',
#  'weno',
#  'bubaque',
#  'champerico',
#  'page',
#  'diego de almagro',
#  'es castell',
#  'biltine',
#  'mudbidri',
#  'san rafael del sur',
#  'stanthorpe',
#  'roma',
#  'puerto san jose',
#  'port augusta',
#  'ad darb',
#  'puerto quijarro',
#  'el granada',
#  'dryden',
#  'copala',
#  'intendente alvear',
#  'ranau',
#  'howrah',
#  'shimoda',
#  'cuatro cienegas de carranza',
#  'sabha',
#  'beitbridge',
#  'nguigmi',
#  'punata',
#  'balkanabat',
#  'houma',
#  "ivdel'",
#  'bodo',
#  'alvorada',
#  'kukmor',
#  'guanica',
#  'soio',
#  'dno',
#  'kirakira',
#  'rincon',
#  'bodaybo',
#  'boende',
#  'kendari',
#  'karatas',
#  'carolina beach',
#  'chernyshevskiy',
#  'ghadamis']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"
print(url + "&q=san francisco")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&appid=d12ca63b051f525dffca0c63330c24c0&q=san francisco

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | puerto natales
# Processing Record 3 of Set 1 | grytviken
# Processing Record 4 of Set 1 | blackwell
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | edinburgh of the seven seas
# Processing Record 7 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 8 of Set 1 | yeed
# Processing Record 9 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 10 of Set 1 | merke
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | youssoufia
# Processing Record 13 of Set 1 | hailar
# Processing Record 14 of Set 1 | bac lieu
# Processing Record 15 of Set 1 | hadibu
# Processing Record 16 of Set 1 | labrador city
# Processing Record 17 of Set 1 | ha tien
# Processing Record 18 of Set 1 | callao
# Processing Record 19 of Set 1 | liupanshui
# City not found. Skipping...
# Processing Record 20 of Set 1 | blackmans bay
# Processing Record 21 of Set 1 | susuman
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | aasiaat
# Processing Record 24 of Set 1 | qaqortoq
# Processing Record 25 of Set 1 | hawaiian paradise park
# Processing Record 26 of Set 1 | villa bruzual
# Processing Record 27 of Set 1 | barah
# Processing Record 28 of Set 1 | acarau
# Processing Record 29 of Set 1 | waitangi
# Processing Record 30 of Set 1 | touros
# Processing Record 31 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 32 of Set 1 | buka
# Processing Record 33 of Set 1 | margaret river
# Processing Record 34 of Set 1 | khovd
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | hasaki
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | huarmey
# Processing Record 39 of Set 1 | xaloztoc
# Processing Record 40 of Set 1 | badger
# Processing Record 41 of Set 1 | ribeirao pires
# Processing Record 42 of Set 1 | hoxtolgay
# City not found. Skipping...
# Processing Record 43 of Set 1 | akrehamn
# Processing Record 44 of Set 1 | vishnyeva
# Processing Record 45 of Set 1 | lihue
# Processing Record 46 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 47 of Set 1 | tual
# Processing Record 48 of Set 1 | invercargill
# Processing Record 49 of Set 1 | uliastay
# Processing Record 50 of Set 1 | kapuskasing
# Processing Record 0 of Set 2 | iskateley
# Processing Record 1 of Set 2 | pasuquin
# Processing Record 2 of Set 2 | longyearbyen
# Processing Record 3 of Set 2 | belomorsk
# Processing Record 4 of Set 2 | padam
# City not found. Skipping...
# Processing Record 5 of Set 2 | saldanha
# Processing Record 6 of Set 2 | adamstown
# Processing Record 7 of Set 2 | rio grande
# Processing Record 8 of Set 2 | kashgar
# Processing Record 9 of Set 2 | sergeyevka
# Processing Record 10 of Set 2 | haiku-pauwela
# Processing Record 11 of Set 2 | sarakhs
# Processing Record 12 of Set 2 | stanley
# Processing Record 13 of Set 2 | atafu village
# Processing Record 14 of Set 2 | ocean city
# Processing Record 15 of Set 2 | wittenburg
# Processing Record 16 of Set 2 | bethel
# Processing Record 17 of Set 2 | hakkari
# Processing Record 18 of Set 2 | ingeniero jacobacci
# Processing Record 19 of Set 2 | tsiombe
# Processing Record 20 of Set 2 | port mathurin
# Processing Record 21 of Set 2 | salekhard
# Processing Record 22 of Set 2 | isafjordur
# Processing Record 23 of Set 2 | ciudad lazaro cardenas
# Processing Record 24 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 2 | tondano
# Processing Record 26 of Set 2 | ilulissat
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | bilibino
# Processing Record 29 of Set 2 | nuku'alofa
# Processing Record 30 of Set 2 | knin
# Processing Record 31 of Set 2 | luderitz
# Processing Record 32 of Set 2 | portland
# Processing Record 33 of Set 2 | hithadhoo
# Processing Record 34 of Set 2 | pisco
# Processing Record 35 of Set 2 | upata
# Processing Record 36 of Set 2 | sola
# Processing Record 37 of Set 2 | basco
# Processing Record 38 of Set 2 | tofol
# Processing Record 39 of Set 2 | selfoss
# Processing Record 40 of Set 2 | chonchi
# Processing Record 41 of Set 2 | castillos
# Processing Record 42 of Set 2 | thompson
# Processing Record 43 of Set 2 | las varas
# Processing Record 44 of Set 2 | gadzhiyevo
# Processing Record 45 of Set 2 | sonsorol village
# City not found. Skipping...
# Processing Record 46 of Set 2 | tiksi
# Processing Record 47 of Set 2 | bayanhongor
# Processing Record 48 of Set 2 | ancud
# Processing Record 49 of Set 2 | lorengau
# Processing Record 0 of Set 3 | yuzhno-kurilsk
# Processing Record 1 of Set 3 | mount isa
# Processing Record 2 of Set 3 | utrik
# Processing Record 3 of Set 3 | vadso
# Processing Record 4 of Set 3 | chibougamau
# Processing Record 5 of Set 3 | taiynsha
# Processing Record 6 of Set 3 | tolanaro
# Processing Record 7 of Set 3 | keflavik
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | olyokminsk
# Processing Record 12 of Set 3 | iqaluit
# Processing Record 13 of Set 3 | huicungo
# Processing Record 14 of Set 3 | kodiak
# Processing Record 15 of Set 3 | sisimiut
# Processing Record 16 of Set 3 | kerikeri
# Processing Record 17 of Set 3 | tchintabaraden
# Processing Record 18 of Set 3 | taksimo
# Processing Record 19 of Set 3 | tabuk
# Processing Record 20 of Set 3 | nemuro
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | oamaru
# Processing Record 23 of Set 3 | novyy rogachik
# Processing Record 24 of Set 3 | al ghayzah
# Processing Record 25 of Set 3 | puerto ayora
# Processing Record 26 of Set 3 | kavaratti
# Processing Record 27 of Set 3 | dudinka
# Processing Record 28 of Set 3 | forster
# Processing Record 29 of Set 3 | kruisfontein
# Processing Record 30 of Set 3 | saint-denis
# Processing Record 31 of Set 3 | bima
# Processing Record 32 of Set 3 | brisas de zicatela
# Processing Record 33 of Set 3 | alofi
# Processing Record 34 of Set 3 | san antonio de pale
# Processing Record 35 of Set 3 | san patricio
# Processing Record 36 of Set 3 | nakamura
# Processing Record 37 of Set 3 | mount gambier
# Processing Record 38 of Set 3 | al artawiyah
# Processing Record 39 of Set 3 | hubli
# Processing Record 40 of Set 3 | flying fish cove
# Processing Record 41 of Set 3 | nar'yan-mar
# Processing Record 42 of Set 3 | dalhart
# Processing Record 43 of Set 3 | costa calma
# City not found. Skipping...
# Processing Record 44 of Set 3 | portrush
# Processing Record 45 of Set 3 | vilyuysk
# Processing Record 46 of Set 3 | wajir
# Processing Record 47 of Set 3 | heihe
# Processing Record 48 of Set 3 | mahibadhoo
# Processing Record 49 of Set 3 | west island
# Processing Record 0 of Set 4 | college
# Processing Record 1 of Set 4 | vorgashor
# Processing Record 2 of Set 4 | manicore
# Processing Record 3 of Set 4 | aral
# Processing Record 4 of Set 4 | bertoua
# Processing Record 5 of Set 4 | crane
# Processing Record 6 of Set 4 | papatowai
# Processing Record 7 of Set 4 | margate
# Processing Record 8 of Set 4 | la passe
# Processing Record 9 of Set 4 | udachny
# Processing Record 10 of Set 4 | tura
# Processing Record 11 of Set 4 | woolgoolga
# Processing Record 12 of Set 4 | enewetak
# Processing Record 13 of Set 4 | whitehorse
# Processing Record 14 of Set 4 | fale old settlement
# Processing Record 15 of Set 4 | daru
# Processing Record 16 of Set 4 | urangan
# Processing Record 17 of Set 4 | saipan
# Processing Record 18 of Set 4 | vredendal
# Processing Record 19 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 20 of Set 4 | zhangye
# Processing Record 21 of Set 4 | hermanus
# Processing Record 22 of Set 4 | carutapera
# Processing Record 23 of Set 4 | punta arenas
# Processing Record 24 of Set 4 | labasa
# Processing Record 25 of Set 4 | anna regina
# Processing Record 26 of Set 4 | labytnangi
# Processing Record 27 of Set 4 | saint-philippe
# Processing Record 28 of Set 4 | urengoy
# Processing Record 29 of Set 4 | nantucket
# Processing Record 30 of Set 4 | ust-nera
# Processing Record 31 of Set 4 | tshikapa
# Processing Record 32 of Set 4 | kudat
# Processing Record 33 of Set 4 | antonio enes
# Processing Record 34 of Set 4 | lebu
# Processing Record 35 of Set 4 | ribeira grande
# Processing Record 36 of Set 4 | minas novas
# Processing Record 37 of Set 4 | sorsk
# Processing Record 38 of Set 4 | ballina
# Processing Record 39 of Set 4 | guilmaro
# City not found. Skipping...
# Processing Record 40 of Set 4 | antalaha
# Processing Record 41 of Set 4 | caluula
# Processing Record 42 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 43 of Set 4 | klyuchi
# Processing Record 44 of Set 4 | qashyr
# Processing Record 45 of Set 4 | katsuura
# Processing Record 46 of Set 4 | flin flon
# Processing Record 47 of Set 4 | altai
# Processing Record 48 of Set 4 | vernon
# Processing Record 49 of Set 4 | mata-utu
# Processing Record 0 of Set 5 | phibun mangsahan
# Processing Record 1 of Set 5 | ulladulla
# Processing Record 2 of Set 5 | port lincoln
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | lucas
# Processing Record 5 of Set 5 | wailua homesteads
# Processing Record 6 of Set 5 | fortaleza
# Processing Record 7 of Set 5 | thunder bay
# Processing Record 8 of Set 5 | akureyri
# Processing Record 9 of Set 5 | colonia
# Processing Record 10 of Set 5 | fort bragg
# Processing Record 11 of Set 5 | noumea
# Processing Record 12 of Set 5 | kingston
# Processing Record 13 of Set 5 | constantia
# Processing Record 14 of Set 5 | hami
# Processing Record 15 of Set 5 | codrington
# Processing Record 16 of Set 5 | morehead city
# Processing Record 17 of Set 5 | mexico
# Processing Record 18 of Set 5 | conception bay south
# Processing Record 19 of Set 5 | poso
# Processing Record 20 of Set 5 | ituiutaba
# Processing Record 21 of Set 5 | tineo
# Processing Record 22 of Set 5 | sao jose da coroa grande
# Processing Record 23 of Set 5 | karratha
# Processing Record 24 of Set 5 | campo gallo
# Processing Record 25 of Set 5 | sorong
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | adrar
# Processing Record 28 of Set 5 | santa terezinha
# Processing Record 29 of Set 5 | hirara
# Processing Record 30 of Set 5 | palia kalan
# Processing Record 31 of Set 5 | arenapolis
# Processing Record 32 of Set 5 | kapa'a
# Processing Record 33 of Set 5 | novodvinsk
# Processing Record 34 of Set 5 | vorkuta
# Processing Record 35 of Set 5 | olonkinbyen
# Processing Record 36 of Set 5 | amasra
# Processing Record 37 of Set 5 | umluj
# Processing Record 38 of Set 5 | sept-iles
# Processing Record 39 of Set 5 | thanh hoa
# Processing Record 40 of Set 5 | port alfred
# Processing Record 41 of Set 5 | angra do heroismo
# Processing Record 42 of Set 5 | dazuocun
# Processing Record 43 of Set 5 | jordanow
# Processing Record 44 of Set 5 | swakopmund
# Processing Record 45 of Set 5 | piti village
# Processing Record 46 of Set 5 | howard springs
# Processing Record 47 of Set 5 | sao felix do xingu
# Processing Record 48 of Set 5 | ola
# Processing Record 49 of Set 5 | ouellah
# City not found. Skipping...
# Processing Record 0 of Set 6 | waukee
# Processing Record 1 of Set 6 | tyuratam
# Processing Record 2 of Set 6 | xique xique
# Processing Record 3 of Set 6 | nyurba
# Processing Record 4 of Set 6 | batticaloa
# Processing Record 5 of Set 6 | port elizabeth
# Processing Record 6 of Set 6 | shalqar
# Processing Record 7 of Set 6 | nea moudhania
# City not found. Skipping...
# Processing Record 8 of Set 6 | tazovsky
# Processing Record 9 of Set 6 | at taj
# Processing Record 10 of Set 6 | awjilah
# Processing Record 11 of Set 6 | new norfolk
# Processing Record 12 of Set 6 | sagua la grande
# Processing Record 13 of Set 6 | alaghsas
# Processing Record 14 of Set 6 | aykhal
# Processing Record 15 of Set 6 | east london
# Processing Record 16 of Set 6 | mejit
# Processing Record 17 of Set 6 | dabat
# Processing Record 18 of Set 6 | sitka
# Processing Record 19 of Set 6 | westport
# Processing Record 20 of Set 6 | cockburn town
# Processing Record 21 of Set 6 | murzuq
# Processing Record 22 of Set 6 | sandnessjoen
# Processing Record 23 of Set 6 | zangguy
# City not found. Skipping...
# Processing Record 24 of Set 6 | springbok
# Processing Record 25 of Set 6 | shorkot
# Processing Record 26 of Set 6 | bayindir
# Processing Record 27 of Set 6 | cornelio procopio
# Processing Record 28 of Set 6 | mirto
# Processing Record 29 of Set 6 | kwang binh
# Processing Record 30 of Set 6 | hamilton
# Processing Record 31 of Set 6 | viradouro
# Processing Record 32 of Set 6 | plouzane
# Processing Record 33 of Set 6 | dunedin
# Processing Record 34 of Set 6 | salahonda
# Processing Record 35 of Set 6 | talnakh
# Processing Record 36 of Set 6 | guerrero negro
# Processing Record 37 of Set 6 | dongcun
# Processing Record 38 of Set 6 | mil'kovo
# Processing Record 39 of Set 6 | pimentel
# Processing Record 40 of Set 6 | ribeira brava
# Processing Record 41 of Set 6 | papao
# Processing Record 42 of Set 6 | isangel
# Processing Record 43 of Set 6 | san julian
# Processing Record 44 of Set 6 | sungai raya
# Processing Record 45 of Set 6 | najran
# Processing Record 46 of Set 6 | santo antonio
# Processing Record 47 of Set 6 | puerto aysen
# Processing Record 48 of Set 6 | rawah
# Processing Record 49 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 0 of Set 7 | salinopolis
# Processing Record 1 of Set 7 | gambela
# Processing Record 2 of Set 7 | kailua-kona
# Processing Record 3 of Set 7 | dalandzadgad
# Processing Record 4 of Set 7 | sao joao da ponte
# Processing Record 5 of Set 7 | talara
# Processing Record 6 of Set 7 | lompoc
# Processing Record 7 of Set 7 | pahrump
# Processing Record 8 of Set 7 | bazas
# Processing Record 9 of Set 7 | yangor
# City not found. Skipping...
# Processing Record 10 of Set 7 | boumahra ahmed
# Processing Record 11 of Set 7 | san antonio oeste
# Processing Record 12 of Set 7 | fort mcmurray
# Processing Record 13 of Set 7 | island harbour
# Processing Record 14 of Set 7 | marsa alam
# Processing Record 15 of Set 7 | kununurra
# Processing Record 16 of Set 7 | bansi
# Processing Record 17 of Set 7 | st. john's
# Processing Record 18 of Set 7 | cabo san lucas
# Processing Record 19 of Set 7 | gizo
# Processing Record 20 of Set 7 | aitape
# Processing Record 21 of Set 7 | san luis de la loma
# Processing Record 22 of Set 7 | coquimbo
# Processing Record 23 of Set 7 | yarmouth
# Processing Record 24 of Set 7 | walvis bay
# Processing Record 25 of Set 7 | masterton
# Processing Record 26 of Set 7 | veymandoo
# City not found. Skipping...
# Processing Record 27 of Set 7 | puerto santander
# Processing Record 28 of Set 7 | harstad
# Processing Record 29 of Set 7 | paita
# Processing Record 30 of Set 7 | pemangkat
# Processing Record 31 of Set 7 | suntar
# Processing Record 32 of Set 7 | yaren
# Processing Record 33 of Set 7 | anadyr
# Processing Record 34 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 35 of Set 7 | kataragama
# City not found. Skipping...
# Processing Record 36 of Set 7 | maysville
# Processing Record 37 of Set 7 | cabedelo
# Processing Record 38 of Set 7 | kone
# Processing Record 39 of Set 7 | smithers
# Processing Record 40 of Set 7 | san fernando de apure
# Processing Record 41 of Set 7 | alto araguaia
# Processing Record 42 of Set 7 | kuala terengganu
# Processing Record 43 of Set 7 | popondetta
# Processing Record 44 of Set 7 | tralee
# Processing Record 45 of Set 7 | tapes
# Processing Record 46 of Set 7 | srivardhan
# Processing Record 47 of Set 7 | am timan
# Processing Record 48 of Set 7 | mahdia
# Processing Record 49 of Set 7 | arris
# Processing Record 0 of Set 8 | porto velho
# Processing Record 1 of Set 8 | kayar
# Processing Record 2 of Set 8 | kiama
# Processing Record 3 of Set 8 | kapoeta
# Processing Record 4 of Set 8 | kaga bandoro
# Processing Record 5 of Set 8 | bikenibeu village
# Processing Record 6 of Set 8 | burang
# Processing Record 7 of Set 8 | novyy urengoy
# Processing Record 8 of Set 8 | montrose
# Processing Record 9 of Set 8 | coahuayana de hidalgo
# Processing Record 10 of Set 8 | abancay
# Processing Record 11 of Set 8 | tawau
# Processing Record 12 of Set 8 | ocean shores
# Processing Record 13 of Set 8 | calama
# Processing Record 14 of Set 8 | sijunjung
# Processing Record 15 of Set 8 | broome
# Processing Record 16 of Set 8 | rongelap
# Processing Record 17 of Set 8 | mozarlandia
# Processing Record 18 of Set 8 | mathba
# Processing Record 19 of Set 8 | beloyarskiy
# Processing Record 20 of Set 8 | carnarvon
# Processing Record 21 of Set 8 | kansanshi
# Processing Record 22 of Set 8 | muscatine
# Processing Record 23 of Set 8 | puerto lempira
# Processing Record 24 of Set 8 | vilaka
# Processing Record 25 of Set 8 | sullivan
# Processing Record 26 of Set 8 | ilanskiy
# Processing Record 27 of Set 8 | al kharijah
# Processing Record 28 of Set 8 | sao vicente
# Processing Record 29 of Set 8 | panaba
# Processing Record 30 of Set 8 | dashitou
# Processing Record 31 of Set 8 | zaozersk
# Processing Record 32 of Set 8 | severo-yeniseyskiy
# Processing Record 33 of Set 8 | tariba
# Processing Record 34 of Set 8 | las heras
# Processing Record 35 of Set 8 | hovd
# Processing Record 36 of Set 8 | lata
# Processing Record 37 of Set 8 | raja
# Processing Record 38 of Set 8 | poteau
# Processing Record 39 of Set 8 | presque isle
# Processing Record 40 of Set 8 | chos malal
# Processing Record 41 of Set 8 | east grand forks
# Processing Record 42 of Set 8 | agua prieta
# Processing Record 43 of Set 8 | kushtia
# Processing Record 44 of Set 8 | wladyslawowo
# Processing Record 45 of Set 8 | gamba
# Processing Record 46 of Set 8 | ponta delgada
# Processing Record 47 of Set 8 | harlingen
# Processing Record 48 of Set 8 | altpinar
# Processing Record 49 of Set 8 | masuguru
# Processing Record 0 of Set 9 | butembo
# Processing Record 1 of Set 9 | vilyuchinsk
# Processing Record 2 of Set 9 | la ronge
# Processing Record 3 of Set 9 | bahar
# Processing Record 4 of Set 9 | bandar lampung
# Processing Record 5 of Set 9 | dan khun thot
# Processing Record 6 of Set 9 | greymouth
# Processing Record 7 of Set 9 | tazacorte
# Processing Record 8 of Set 9 | arteche
# Processing Record 9 of Set 9 | kuching
# Processing Record 10 of Set 9 | deqen
# Processing Record 11 of Set 9 | dobryanka
# Processing Record 12 of Set 9 | cooper's town
# Processing Record 13 of Set 9 | qasr-e qand
# City not found. Skipping...
# Processing Record 14 of Set 9 | tadine
# Processing Record 15 of Set 9 | timmins
# Processing Record 16 of Set 9 | brokopondo
# Processing Record 17 of Set 9 | batangafo
# Processing Record 18 of Set 9 | gokwe
# Processing Record 19 of Set 9 | prince rupert
# Processing Record 20 of Set 9 | nova sintra
# Processing Record 21 of Set 9 | jurbarkas
# Processing Record 22 of Set 9 | simpang
# Processing Record 23 of Set 9 | quellon
# Processing Record 24 of Set 9 | bandraboua
# Processing Record 25 of Set 9 | la'ie
# Processing Record 26 of Set 9 | bhimbar
# Processing Record 27 of Set 9 | wanning
# Processing Record 28 of Set 9 | torbat-e jam
# Processing Record 29 of Set 9 | shangqiu
# Processing Record 30 of Set 9 | san jose del guaviare
# Processing Record 31 of Set 9 | xining
# Processing Record 32 of Set 9 | berezivka
# Processing Record 33 of Set 9 | mukah
# City not found. Skipping...
# Processing Record 34 of Set 9 | tarawa
# Processing Record 35 of Set 9 | uturoa
# Processing Record 36 of Set 9 | iquique
# Processing Record 37 of Set 9 | geraldton
# Processing Record 38 of Set 9 | tahe
# Processing Record 39 of Set 9 | ikere-ekiti
# Processing Record 40 of Set 9 | praia da vitoria
# Processing Record 41 of Set 9 | kushiro
# Processing Record 42 of Set 9 | carauari
# Processing Record 43 of Set 9 | port saint john's
# Processing Record 44 of Set 9 | okhotsk
# Processing Record 45 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 46 of Set 9 | myitkyina
# Processing Record 47 of Set 9 | broken hill
# Processing Record 48 of Set 9 | tabou
# Processing Record 49 of Set 9 | nova xavantina
# Processing Record 0 of Set 10 | neka
# Processing Record 1 of Set 10 | aioun
# Processing Record 2 of Set 10 | terrace
# Processing Record 3 of Set 10 | griffith
# Processing Record 4 of Set 10 | itoman
# Processing Record 5 of Set 10 | priob'ye
# Processing Record 6 of Set 10 | revda
# Processing Record 7 of Set 10 | bamboo flat
# Processing Record 8 of Set 10 | buala
# Processing Record 9 of Set 10 | lerwick
# Processing Record 10 of Set 10 | saynshand
# Processing Record 11 of Set 10 | mananara
# Processing Record 12 of Set 10 | yenisehir
# Processing Record 13 of Set 10 | holualoa
# Processing Record 14 of Set 10 | lindisfarne
# Processing Record 15 of Set 10 | tocopilla
# Processing Record 16 of Set 10 | ha'il
# Processing Record 17 of Set 10 | polyarnyy
# Processing Record 18 of Set 10 | toliara
# Processing Record 19 of Set 10 | bakchar
# Processing Record 20 of Set 10 | sars
# Processing Record 21 of Set 10 | vom
# Processing Record 22 of Set 10 | lembar
# City not found. Skipping...
# Processing Record 23 of Set 10 | puttur
# Processing Record 24 of Set 10 | afaahiti
# Processing Record 25 of Set 10 | sukhobezvodnoye
# Processing Record 26 of Set 10 | butha-buthe
# Processing Record 27 of Set 10 | ankang
# Processing Record 28 of Set 10 | launceston
# Processing Record 29 of Set 10 | dashiqiao
# Processing Record 30 of Set 10 | aizkraukle
# Processing Record 31 of Set 10 | kharhial
# Processing Record 32 of Set 10 | tamandare
# Processing Record 33 of Set 10 | goalpara
# Processing Record 34 of Set 10 | port sudan
# Processing Record 35 of Set 10 | north bend
# Processing Record 36 of Set 10 | ghanzi
# Processing Record 37 of Set 10 | freetown
# Processing Record 38 of Set 10 | charkhi dadri
# Processing Record 39 of Set 10 | mogocha
# Processing Record 40 of Set 10 | karbala
# Processing Record 41 of Set 10 | hastings
# Processing Record 42 of Set 10 | nakatsugawa
# Processing Record 43 of Set 10 | namibe
# Processing Record 44 of Set 10 | terekeka
# City not found. Skipping...
# Processing Record 45 of Set 10 | constitucion
# Processing Record 46 of Set 10 | helston
# Processing Record 47 of Set 10 | thinadhoo
# Processing Record 48 of Set 10 | belyy yar
# Processing Record 49 of Set 10 | bossangoa
# Processing Record 0 of Set 11 | fagaras
# Processing Record 1 of Set 11 | kasimov
# Processing Record 2 of Set 11 | riverton
# Processing Record 3 of Set 11 | kota bharu
# Processing Record 4 of Set 11 | sofifi
# City not found. Skipping...
# Processing Record 5 of Set 11 | glace bay
# Processing Record 6 of Set 11 | murun-kuren
# Processing Record 7 of Set 11 | sabang
# Processing Record 8 of Set 11 | lensk
# Processing Record 9 of Set 11 | conde
# Processing Record 10 of Set 11 | novyy urgal
# Processing Record 11 of Set 11 | nadi
# Processing Record 12 of Set 11 | aplahoue
# Processing Record 13 of Set 11 | grahamstown
# Processing Record 14 of Set 11 | box elder
# Processing Record 15 of Set 11 | caleta de carquin
# Processing Record 16 of Set 11 | bridgetown
# Processing Record 17 of Set 11 | ta`u
# Processing Record 18 of Set 11 | el triunfo
# Processing Record 19 of Set 11 | arvayheer
# Processing Record 20 of Set 11 | mili
# Processing Record 21 of Set 11 | wagar
# Processing Record 22 of Set 11 | altamira
# Processing Record 23 of Set 11 | yantzaza
# Processing Record 24 of Set 11 | manado
# Processing Record 25 of Set 11 | lazaro cardenas
# Processing Record 26 of Set 11 | almus
# Processing Record 27 of Set 11 | yarovoye
# Processing Record 28 of Set 11 | weno
# Processing Record 29 of Set 11 | bubaque
# Processing Record 30 of Set 11 | champerico
# Processing Record 31 of Set 11 | page
# Processing Record 32 of Set 11 | diego de almagro
# Processing Record 33 of Set 11 | es castell
# Processing Record 34 of Set 11 | biltine
# Processing Record 35 of Set 11 | mudbidri
# Processing Record 36 of Set 11 | san rafael del sur
# Processing Record 37 of Set 11 | stanthorpe
# Processing Record 38 of Set 11 | roma
# Processing Record 39 of Set 11 | puerto san jose
# Processing Record 40 of Set 11 | port augusta
# Processing Record 41 of Set 11 | ad darb
# Processing Record 42 of Set 11 | puerto quijarro
# Processing Record 43 of Set 11 | el granada
# Processing Record 44 of Set 11 | dryden
# Processing Record 45 of Set 11 | copala
# Processing Record 46 of Set 11 | intendente alvear
# Processing Record 47 of Set 11 | ranau
# Processing Record 48 of Set 11 | howrah
# Processing Record 49 of Set 11 | shimoda
# Processing Record 0 of Set 12 | cuatro cienegas de carranza
# Processing Record 1 of Set 12 | sabha
# Processing Record 2 of Set 12 | beitbridge
# Processing Record 3 of Set 12 | nguigmi
# Processing Record 4 of Set 12 | punata
# Processing Record 5 of Set 12 | balkanabat
# Processing Record 6 of Set 12 | houma
# Processing Record 7 of Set 12 | ivdel'
# Processing Record 8 of Set 12 | bodo
# Processing Record 9 of Set 12 | alvorada
# Processing Record 10 of Set 12 | kukmor
# Processing Record 11 of Set 12 | guanica
# Processing Record 12 of Set 12 | soio
# Processing Record 13 of Set 12 | dno
# Processing Record 14 of Set 12 | kirakira
# Processing Record 15 of Set 12 | rincon
# Processing Record 16 of Set 12 | bodaybo
# Processing Record 17 of Set 12 | boende
# Processing Record 18 of Set 12 | kendari
# Processing Record 19 of Set 12 | karatas
# Processing Record 20 of Set 12 | carolina beach
# Processing Record 21 of Set 12 | chernyshevskiy
# Processing Record 22 of Set 12 | ghadamis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          547
# Lat           547
# Lng           547
# Max Temp      547
# Humidity      547
# Cloudiness    547
# Wind Speed    547
# Country       547
# Date          547
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500  70.2167      5.06        90         100
# 1     puerto natales -51.7236 -72.4875      0.93        94          98
# 2          grytviken -54.2811 -36.5092      1.68        89          30
# 3          blackwell  36.8045 -97.2828     11.08        87          40
# 4            ushuaia -54.8000 -68.3000      3.81        48          20
#
#    Wind Speed Country        Date
# 0       16.77      TF  1700121507
# 1        1.94      CL  1700121507
# 2        2.91      GS  1700121508
# 3        0.00      US  1700121508
# 4        4.63      AR  1700121508

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500  70.2167      5.06        90         100
# 1           puerto natales -51.7236 -72.4875      0.93        94          98
# 2                grytviken -54.2811 -36.5092      1.68        89          30
# 3                blackwell  36.8045 -97.2828     11.08        87          40
# 4                  ushuaia -54.8000 -68.3000      3.81        48          20
#
#          Wind Speed Country        Date
# City_ID
# 0             16.77      TF  1700121507
# 1              1.94      CL  1700121507
# 2              2.91      GS  1700121508
# 3              0.00      US  1700121508
# 4              4.63      AR  1700121508

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
import time
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor="red",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Max Latitude vs. Temperature ({date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor="green",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)
# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Max Latitude vs. Humidity ({date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor="purple",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Max Latitude vs. Cloudiness ({date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    edgecolor="pink",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (%)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_value, y_value, title, text_coord):
   
    #Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_value = x_value * slope + intercept
    line_eq = f"y = {round(slope,2)}x + {round(intercept,2)}"
    
    plt.scatter(x_value, y_value)
    plt.plot(x_values, regress_value, "r-")
    plt.annotate(line_eq, text_coord, fontsize=15, color="red")
    plt.xlabel("Lat")
    plt.ylabel(title)
    print(f"The r-value is{rvalue ** 2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 3                       blackwell  36.8045  -97.2828     11.08        87
# 6        petropavlovsk-kamchatsky  53.0452  158.6483     -4.67        63
# 7                            yeed   4.5500   43.0333     28.62        62
# 8                           merke  42.8728   73.1786     20.37        14
# 9                     yellowknife  62.4560 -114.3525    -14.69        96
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 3                40        0.00      US  1700121508
# 6                 0        6.26      RU  1700121418
# 7                91        1.55      SO  1700121509
# 8                12        1.72      KZ  1700121511
# 9               100        2.06      CA  1700121292

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] <0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0                  port-aux-francais -49.3500  70.2167      5.06        90
# 1                     puerto natales -51.7236 -72.4875      0.93        94
# 2                          grytviken -54.2811 -36.5092      1.68        89
# 4                            ushuaia -54.8000 -68.3000      3.81        48
# 5        edinburgh of the seven seas -37.0676 -12.3116     13.38        74
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100       16.77      TF  1700121507
# 1                98        1.94      CL  1700121507
# 2                30        2.91      GS  1700121508
# 4                20        4.63      AR  1700121508
# 5                44        9.44      SH  1700121509

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (6, -10))
# Out:
# The r-value is0.8142404190292931

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-55, 35))
# Out:
# The r-value is0.5372892069202116

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (40, 15))
# Out:
# The r-value is0.07269521618177491

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-55, 20))
# Out:
# The r-value is0.009652303007065616

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "CLoudiness", (50, 15))
# Out:
# The r-value is0.016513612793734065

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (-55, 15))
# Out:
# The r-value is0.005751883592479853

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (10, 14))
# Out:
# The r-value is0.0019452668302592992

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-55, 14))
# Out:
# The r-value is0.05870082952278956

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
